# %%
import tweepy
from tweepy import OAuthHandler

# %%
consumer_key='KsfC6VJ78QIYWsleKfXRPuNG1'
consumer_secret_key='HuDujjBLyGvAZ2nv1v427gug1kdedpVe0YzfdJHnS0DOBftgiY'
access_token='2875444098-oNEvzGxAIhBNVgmBiY7S94maFV7h856m3oDe3uF'
access_secret='WpSKJkUEKuJuV3t0yRApJSXevOd7y0P2dOGor0eVs3ux4'

auth=OAuthHandler(consumer_key, consumer_secret_key)
auth.set_access_token(access_token, access_secret)

# %%
api=tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    print(status.text)
# Out:
# He is threatening every one forgetting that other people (read current dispensation) too can return the favour and… https://t.co/gZj68ar707
# As the elites get kicked out of each party, we are going from Republicans vs Democrats to Populists vs Socialists.
# A new era of #supersonic flight is almost upon us, watch to know more about the #engine that’s making this possible… https://t.co/szFOtAeKrF
# RT @businessinsider: A updated version of the VW bus is coming back — it will be an all-electric vehicle https://t.co/TpA7bTsy24
# 4 days at CES: The best surprises, the worst disappointments https://t.co/KbjrTSXKow
# #HappyMakarSankranti to everyone! https://t.co/9LnlZWGDiB
# RT @DDNewsLive: With @indiannavy's DSRV, India joins elite group of nations that possess capability to rescue submariners in deep seas http…
# These stunning pies are works of art https://t.co/HdevnDHWA1
# "If it weren't for Randy, who knows how things would have ended." https://t.co/2tevjqZauw
# ...

# %%
results=[]
for tweet in tweepy.Cursor(api.search, q="#narendramodi", lang='en', since="2018-6-05").items(2000):
    results.append(tweet)

# %%
import pandas as pd

# %%
def tweet_df(results):
    id_list= [tweet.id for tweet in results]
    dataset=pd.DataFrame(id_list, columns=['id'])
    
    dataset["text"]=[tweet.text for tweet in results]
    dataset['retweet']= [tweet.retweet for tweet in results]
    dataset['hashtag']=[tweet.entities.get('hashtag') for tweet in results]
    dataset['user_location']=[tweet.author.location for tweet in results]
    dataset['screen_name']=[tweet.author.screen_name for tweet in results]
    
    return dataset

dataset= tweet_df(results)

# %%
text=dataset["text"]

for i in range(0, len(text)):
    txt=' '.join(word for word in text[i].split() if not word.startswith('https:'))
    dataset.set_value(i, 'text2', txt)

dataset.drop_duplicates('text2', inplace=True)
dataset.reset_index(drop= True, inplace=True)
dataset.drop('text', axis =1, inplace=True)
dataset.rename(columns={'text2': 'text'}, inplace=True)
# Out:
# C:\Users\prash\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """

# %%
dataset
# Out:
#                        id                                            retweet  \
# 0     1084717632551477248  <bound method Status.retweet of Status(_api=<t...
# 1     1084716459559972864  <bound method Status.retweet of Status(_api=<t...
# 2     1084714649977643009  <bound method Status.retweet of Status(_api=<t...
# 3     1084713322816008194  <bound method Status.retweet of Status(_api=<t...
# 4     1084712762767421445  <bound method Status.retweet of Status(_api=<t...
# 5     1084711863693307905  <bound method Status.retweet of Status(_api=<t...
# 6     1084711047234113537  <bound method Status.retweet of Status(_api=<t...
# 7     1084710552310595584  <bound method Status.retweet of Status(_api=<t...
# 8     1084709698861813760  <bound method Status.retweet of Status(_api=<t...
# 9     1084708982776885253  <bound method Status.retweet of Status(_api=<t...
# 10    1084707345144283137  <bound method Status.retweet of Status(_api=<t...
# ...

# %%
import operator

# %%
from textblob import TextBlob

# %%
from textblob import Word
from textblob.sentiments import NaiveBayesAnalyzer

# %%
text=dataset["text"]

for i in range(0, len(text)):
    textB= TextBlob(text[i])
    sentiment=textB.sentiment.polarity
    dataset.set_value(i, 'sentiment', sentiment)
    if sentiment<0.0:
        sentiment='Negative'
        dataset.set_value(i, 'SentimentClass', sentiment)
    elif sentiment>0.0:
        sentiment='positive'
        dataset.set_value(i, 'SentimentClass', sentiment)
    else:
        sentiment='neutral'
        dataset.set_value(i, 'SentimentClass', sentiment)
# Out:
# C:\Users\prash\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\prash\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Users\prash\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\prash\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':

# %%
dataset
# Out:
#                        id                                            retweet  \
# 0     1084717632551477248  <bound method Status.retweet of Status(_api=<t...
# 1     1084716459559972864  <bound method Status.retweet of Status(_api=<t...
# 2     1084714649977643009  <bound method Status.retweet of Status(_api=<t...
# 3     1084713322816008194  <bound method Status.retweet of Status(_api=<t...
# 4     1084712762767421445  <bound method Status.retweet of Status(_api=<t...
# 5     1084711863693307905  <bound method Status.retweet of Status(_api=<t...
# 6     1084711047234113537  <bound method Status.retweet of Status(_api=<t...
# 7     1084710552310595584  <bound method Status.retweet of Status(_api=<t...
# 8     1084709698861813760  <bound method Status.retweet of Status(_api=<t...
# 9     1084708982776885253  <bound method Status.retweet of Status(_api=<t...
# 10    1084707345144283137  <bound method Status.retweet of Status(_api=<t...
# ...

# %%
text[2]
# Out:
# 'RT @airnewsalerts: Prime Minister #NarendraModi says, BJP is in politics to serve the nation, but other parties want to divide and rule and…'

# %%
import matplotlib.pyplot as plt

# %%
y=[3,10,9,7,5,9,4,3]

# %%
N=len(y)

# %%
x=range(N)

# %%
width=.5

# %%
plt.bar(x,y,width, color="red")
# Out:
# <BarContainer object of 8 artists>
